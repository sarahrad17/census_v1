# %%
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d

# %%
high_s = [0.7514220705346986, 0.6908418657565415, 0.6043799772468714, 0.47440273037542663, 0.3575085324232082, 0.23720136518771331, 0.1561433447098976, 0.11518771331058021, 0.08646188850967008, 0.04948805460750853, 0.03043230944254835, 0.012229806598407281]
med_s = [0.4487365669474296, 0.38164391519024105, 0.3296543711879175, 0.24368283473714783, 0.1716526285216381, 0.12750508277664827, 0.09933197792622712, 0.07115887307580598, 0.05837932036015103, 0.030496659889631135, 0.017426662794074933, 0.007841998257333721]
low_s = [0.3364914425427873, 0.2866748166259169, 0.2558068459657702, 0.18856968215158923, 0.13416870415647922, 0.11430317848410758, 0.097799511002445, 0.06723716381418093, 0.05134474327628362, 0.03025672371638142, 0.011919315403422982, 0.007946210268948655]
s = [high_s, med_s, low_s]


high = [0.08500951146742224, 0.23196666572737415, 0.45508301683471003, 0.5573706717680686, 0.5474824125052321,  0.5574058600009412,  0.543371634997356, 0.5622432442388193, 0.5786734428748005, 0.5474076378300051, 0.6110334767728047, 0.5840190842903747]
med = [0.1732251082251082, 0.3628873622351883, 0.4879989999752845, 0.5815810973781989,  0.607680082933706, 0.607413326966467, 0.6424139427400296, 0.6270490359077315, 0.6395935023108936, 0.6729099657722846, 0.6499954165533876, 0.6063059472002159]
low = [0.3050595238095239, 0.4597883597883598, 0.6096825396825397, 0.5100907029478458, 0.5871428571428571, 0.571201814058957, 0.6013888888888889, 0.6472619047619048, 0.6028571428571429, 0.5756613756613757, 0.6163359788359788, 0.6273015873015874]

h = [high, med, low]

labels = ['High Diversity Population', 'Medium Diversity Population', 'Low Diversity Population']

swap = [0.01, 0.060000000000000005, 0.11, 0.21000000000000002, 0.31000000000000005, 0.41000000000000003,
                  0.51, 0.6100000000000001, 0.7100000000000001, 0.81, 0.91, 0.9600000000000001]

# %%
fig=plt.figure()
plt.figure(figsize=(15,8))
axes = plt.axes(projection='3d')

axes.set_xlabel("Swap Rate")
axes.set_ylabel("Vulnerability Rate (Low Privacy)")
axes.set_zlabel("Mean Difference Error (Low Accuracy)")

for i in range(0,len(s)):
    line=axes.plot3D(swap,h[i],s[i], label=labels[i])
    
handles, labels = axes.get_legend_handles_labels()
axes.legend(handles, labels)

# %%
high_div_similar = [[ 821+683+1138, 400+326+662], 
                    [ 731+638+1060, 327+291+600], 
                    [604+572+949, 239+240+515], 
                    [ 478+453+737, 190+196+348], 
                    [ 333+348+576, 142+171+289], 
                    [ 201+243+390, 93+131+209]]


med_div_similar = [[410+458+677, 153+155+298],  
                   [ 346+385+583, 109+101+238], 
                   [ 301+331+503, 95+79+187], 
                   [ 238+235+366, 77+69+154], 
                   [ 177+173+241, 72+55+111], 
                   [ 144+127+168, 64+46+79]]

low_div_similar = [[355+392+354, 62+98+95], 
                   [308+328+302, 54+68+64], 
                   [299+279+259, 62+68+56], 
                   [ 210+207+200, 62+61+61], 
                   [ 161+159+119, 55+47+46], 
                   [ 121+131+120, 38+49+34], 
                   [132+100+88, 41+28+28]]
